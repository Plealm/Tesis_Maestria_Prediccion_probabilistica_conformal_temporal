# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from pipeline import Pipeline240_ProporcionesVariables

# Para ARMA (más rápido)
pipeline = Pipeline240_ProporcionesVariables(
    n_boot=1000,
    seed=42,
    verbose=False,
    proceso_tipo='ARMA'
)

df_arma = pipeline.run_all(
    excel_filename="ARMA_240_FINAL.xlsx",
    batch_size=30,      # Óptimo
    max_workers=None,   # Auto (80% cores)
    save_frequency=2    # Cada 720 filas
)
# Out:
# ============================================================
# 📊 CONFIGURACIÓN VALIDADA:
#    • Configs ARMA: 7
#    • Proporciones: 5
#    • Distribuciones: 5
#    • Varianzas: 4
#    • Escenarios totales: 700
#    • Filas esperadas: 8400 (25,200)
# ============================================================
#
# 🚀 INICIANDO PIPELINE - ARMA
#    📦 Batches: 24 (tamaño 30)
#    👷 Workers: 12/16 cores
#    💾 Guardado cada 2 batches (720 filas)
#
# 🔄 Batch 1/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 2/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 1: 720 filas guardadas
# 🔄 Batch 3/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 4/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 2: 1440 filas guardadas
# 🔄 Batch 5/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 6/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 3: 2160 filas guardadas
# 🔄 Batch 7/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 8/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 4: 2880 filas guardadas
# 🔄 Batch 9/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 10/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 5: 3600 filas guardadas
# 🔄 Batch 11/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 12/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 6: 4320 filas guardadas
# 🔄 Batch 13/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 14/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 7: 5040 filas guardadas
# 🔄 Batch 15/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 16/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 8: 5760 filas guardadas
# 🔄 Batch 17/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 18/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 9: 6480 filas guardadas
# 🔄 Batch 19/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 20/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 10: 7200 filas guardadas
# 🔄 Batch 21/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 22/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 11: 7920 filas guardadas
# 🔄 Batch 23/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 24/24 (10 escenarios)... ✅ 480 filas
#    💾 Checkpoint 12: 8400 filas guardadas
#
# ============================================================
# 🎉 PIPELINE COMPLETADO
#    📊 Filas obtenidas: 8400
#    ✅ Filas esperadas: 8400
#    ✅ VALIDACIÓN EXITOSA: 25,200 filas
#    📁 Archivo: ARMA_240_FINAL.xlsx
# ============================================================
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 19
#      11 df_arma = pipeline.run_all(
#      12     excel_filename="ARMA_240_FINAL.xlsx",
#      13     batch_size=30,      # Óptimo
#      14     max_workers=None,   # Auto (80% cores)
#      15     save_frequency=2    # Cada 720 filas
#      16 )
#      18 # Validar resultado
# ---> 19 assert len(df_arma) == 25200, "Error: filas incorrectas"
#
# AssertionError: Error: filas incorrectas

# %%
from pipeline import Pipeline240_ProporcionesVariables

# Para ARIMA (más rápido)
pipeline = Pipeline240_ProporcionesVariables(
    n_boot=1000,
    seed=42,
    verbose=False,
    proceso_tipo='ARIMA'
)

df_ARIMA = pipeline.run_all(
    excel_filename="ARIMA_240_FINAL.xlsx",
    batch_size=30,      # Óptimo
    max_workers=None,   # Auto (80% cores)
    save_frequency=2    # Cada 720 filas
)
# Out:
# ============================================================
# 📊 CONFIGURACIÓN VALIDADA:
#    • Configs ARIMA: 7
#    • Proporciones: 5
#    • Distribuciones: 5
#    • Varianzas: 4
#    • Escenarios totales: 700
#    • Filas esperadas: 8400 (25,200)
# ============================================================
#
# 🚀 INICIANDO PIPELINE - ARIMA
#    📦 Batches: 24 (tamaño 30)
#    👷 Workers: 12/16 cores
#    💾 Guardado cada 2 batches (720 filas)
#
# 🔄 Batch 1/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 2/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 1: 720 filas guardadas
# 🔄 Batch 3/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 4/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 2: 1440 filas guardadas
# 🔄 Batch 5/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 6/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 3: 2160 filas guardadas
# 🔄 Batch 7/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 8/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 4: 2880 filas guardadas
# 🔄 Batch 9/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 10/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 5: 3600 filas guardadas
# 🔄 Batch 11/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 12/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 6: 4320 filas guardadas
# 🔄 Batch 13/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 14/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 7: 5040 filas guardadas
# 🔄 Batch 15/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 16/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 8: 5760 filas guardadas
# 🔄 Batch 17/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 18/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 9: 6480 filas guardadas
# 🔄 Batch 19/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 20/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 10: 7200 filas guardadas
# 🔄 Batch 21/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 22/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 11: 7920 filas guardadas
# 🔄 Batch 23/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 24/24 (10 escenarios)... ✅ 480 filas
#    💾 Checkpoint 12: 8400 filas guardadas
#
# ============================================================
# 🎉 PIPELINE COMPLETADO
#    📊 Filas obtenidas: 8400
#    ✅ Filas esperadas: 8400
#    ✅ VALIDACIÓN EXITOSA: 25,200 filas
#    📁 Archivo: ARIMA_240_FINAL.xlsx
# ============================================================

# %%
from pipeline import Pipeline240_ProporcionesVariables

# Para SETAR (más rápido)
pipeline = Pipeline240_ProporcionesVariables(
    n_boot=1000,
    seed=42,
    verbose=False,
    proceso_tipo='SETAR'
)

df_SETAR = pipeline.run_all(
    excel_filename="SETAR_240_FINAL.xlsx",
    batch_size=30,      # Óptimo
    max_workers=None,   # Auto (80% cores)
    save_frequency=2    # Cada 720 filas
)
# Out:
# ============================================================
# 📊 CONFIGURACIÓN VALIDADA:
#    • Configs SETAR: 7
#    • Proporciones: 5
#    • Distribuciones: 5
#    • Varianzas: 4
#    • Escenarios totales: 700
#    • Filas esperadas: 8400 (25,200)
# ============================================================
#
# 🚀 INICIANDO PIPELINE - SETAR
#    📦 Batches: 24 (tamaño 30)
#    👷 Workers: 12/16 cores
#    💾 Guardado cada 2 batches (720 filas)
#
# 🔄 Batch 1/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 2/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 1: 720 filas guardadas
# 🔄 Batch 3/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 4/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 2: 1440 filas guardadas
# 🔄 Batch 5/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 6/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 3: 2160 filas guardadas
# 🔄 Batch 7/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 8/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 4: 2880 filas guardadas
# 🔄 Batch 9/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 10/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 5: 3600 filas guardadas
# 🔄 Batch 11/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 12/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 6: 4320 filas guardadas
# 🔄 Batch 13/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 14/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 7: 5040 filas guardadas
# 🔄 Batch 15/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 16/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 8: 5760 filas guardadas
# 🔄 Batch 17/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 18/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 9: 6480 filas guardadas
# 🔄 Batch 19/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 20/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 10: 7200 filas guardadas
# 🔄 Batch 21/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 22/24 (30 escenarios)... ✅ 720 filas
#    💾 Checkpoint 11: 7920 filas guardadas
# 🔄 Batch 23/24 (30 escenarios)... ✅ 360 filas
# 🔄 Batch 24/24 (10 escenarios)... ✅ 480 filas
#    💾 Checkpoint 12: 8400 filas guardadas
#
# ============================================================
# 🎉 PIPELINE COMPLETADO
#    📊 Filas obtenidas: 8400
#    ✅ Filas esperadas: 8400
#    ✅ VALIDACIÓN EXITOSA: 25,200 filas
#    📁 Archivo: SETAR_240_FINAL.xlsx
# ============================================================

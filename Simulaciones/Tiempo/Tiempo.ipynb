# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from pipeline import SingleScenarioTester

# ==================== EJEMPLO DE USO ====================

if __name__ == "__main__":
    tester = SingleScenarioTester(n_boot=1000, seed=42, verbose=True)
    
    # Ejemplo 1: Probar un ARMA(1,1)
    print("Ejemplo 1: ARMA(1,1)")
    df_arma = tester.test_arma_scenario(
        phi=[0.6],
        theta=[0.3],
        noise_dist='normal',
        variance=1.0
    )
    
    # Ejemplo 2: Probar un ARIMA(1,1,1)
    print("\nEjemplo 2: ARIMA(1,1,1)")
    df_arima = tester.test_arima_scenario(
        phi=[0.7],
        theta=[-0.3],
        noise_dist='t-student',
        variance=0.5
    )
    
    # Ejemplo 3: Probar un SETAR
    print("\nEjemplo 3: SETAR(2;2,2)")
    df_setar = tester.test_setar_scenario(
        phi_regime1=[0.5, -0.2],
        phi_regime2=[-0.3, 0.1],
        threshold=0.5,
        delay=1,
        noise_dist='mixture',
        variance=1.0
    )
# Out:
# Ejemplo 1: ARMA(1,1)
#
# ======================================================================
# 🧪 Probando escenario ARMA: ARMA(1,1)
#    Distribución: normal | Varianza: 1.0
# ======================================================================
#
# ⚙️  Optimizando hiperparámetros...
#
# ⚡ OPTIMIZACIÓN EFICIENTE (Sin límite rígido de tiempo)
#   ✓ Block Bootstrapping: Mejor CRPS=0.9623 [1.3s]
#   ✓ Sieve Bootstrap: Mejor CRPS=0.6251 [1.1s]
#   ✓ LSPMW: Mejor CRPS=0.8991 [0.2s]
#   ✓ AREPD: Mejor CRPS=0.9669 [0.4s]
#     Error en config {'n_lags': 10, 'n_bins': 8}: cannot pickle 'module' object
#     Error en config {'n_lags': 15, 'n_bins': 15}: cannot pickle 'module' object
#   ✓ MCPS: Mejor CRPS=inf [0.0s]
#     Error en config {'n_lags': 10, 'n_pred_bins': 8, 'n_vol_bins': 3}: cannot pickle 'module' object
#     Error en config {'n_lags': 15, 'n_pred_bins': 10, 'n_vol_bins': 5}: cannot pickle 'module' object
#   ✓ AV-MCPS: Mejor CRPS=inf [0.0s]
#   ✓ DeepAR: Mejor CRPS=0.6362 [36.5s]
#     Error en config {'n_lags': 10, 'units': 24, 'epochs': 20}: cannot pickle 'module' object
#     Error en config {'n_lags': 20, 'units': 32, 'epochs': 25}: cannot pickle 'module' object
#   ✓ EnCQR-LSTM: Mejor CRPS=inf [0.0s]
# ✅ Optimización completada en 39.39s
#
# 🔬 Iniciando pruebas en ventana deslizante...
#
#    Paso 1/12... ✓ (20.21s)
#    Paso 2/12... ✓ (0.41s)
#    Paso 3/12... ✓ (0.41s)
#    Paso 4/12... ✓ (0.41s)
#    Paso 5/12... ✓ (0.42s)
#    Paso 6/12... ✓ (0.41s)
#    Paso 7/12... ✓ (0.40s)
#    Paso 8/12... ✓ (0.40s)
#    Paso 9/12... ✓ (0.41s)
#    Paso 10/12... ✓ (0.42s)
#    Paso 11/12... ✓ (0.45s)
#    Paso 12/12... ✓ (0.47s)
#
# ✅ Resultados guardados en: test_results\test_ARMA_ARMA(1,1)_normal_V1.0.xlsx
#
# ======================================================================
#
#
# Ejemplo 2: ARIMA(1,1,1)
#
# ======================================================================
# 🧪 Probando escenario ARIMA: ARIMA(1,1,1)
#    Distribución: t-student | Varianza: 0.5
# ======================================================================
#
# ⚙️  Optimizando hiperparámetros...
#
# ⚡ OPTIMIZACIÓN EFICIENTE (Sin límite rígido de tiempo)
#   ✓ Block Bootstrapping: Mejor CRPS=3.1977 [0.0s]
#   ✓ Sieve Bootstrap: Mejor CRPS=0.3334 [0.3s]
#   ✓ LSPMW: Mejor CRPS=0.5904 [0.1s]
#   ✓ AREPD: Mejor CRPS=2.7792 [0.2s]
#     Error en config {'n_lags': 10, 'n_bins': 8}: cannot pickle 'module' object
#     Error en config {'n_lags': 15, 'n_bins': 15}: cannot pickle 'module' object
#   ✓ MCPS: Mejor CRPS=inf [0.0s]
#     Error en config {'n_lags': 10, 'n_pred_bins': 8, 'n_vol_bins': 3}: cannot pickle 'module' object
#     Error en config {'n_lags': 15, 'n_pred_bins': 10, 'n_vol_bins': 5}: cannot pickle 'module' object
#   ✓ AV-MCPS: Mejor CRPS=inf [0.0s]
#   ✓ DeepAR: Mejor CRPS=0.3683 [41.0s]
#     Error en config {'n_lags': 10, 'units': 24, 'epochs': 20}: cannot pickle 'module' object
#     Error en config {'n_lags': 20, 'units': 32, 'epochs': 25}: cannot pickle 'module' object
#   ✓ EnCQR-LSTM: Mejor CRPS=inf [0.0s]
# ✅ Optimización completada en 41.59s
#
# 🔬 Iniciando pruebas en ventana deslizante...
#
#    Paso 1/12... ✓ (18.63s)
#    Paso 2/12... ✓ (0.38s)
#    Paso 3/12... ✓ (0.39s)
#    Paso 4/12... ✓ (0.39s)
#    Paso 5/12... ✓ (0.38s)
#    Paso 6/12... ✓ (0.38s)
#    Paso 7/12... ✓ (0.39s)
#    Paso 8/12... ✓ (0.41s)
#    Paso 9/12... ✓ (0.41s)
#    Paso 10/12... ✓ (0.38s)
#    Paso 11/12... ✓ (0.39s)
#    Paso 12/12... ✓ (0.40s)
#
# ✅ Resultados guardados en: test_results\test_ARIMA_ARIMA(1,1,1)_t-student_V0.5.xlsx
#
# ======================================================================
#
#
# Ejemplo 3: SETAR(2;2,2)
#
# ======================================================================
# 🧪 Probando escenario SETAR: SETAR(2;2,2)_d1_r0.5
#    Distribución: mixture | Varianza: 1.0
# ======================================================================
#
# ⚙️  Optimizando hiperparámetros...
#
# ⚡ OPTIMIZACIÓN EFICIENTE (Sin límite rígido de tiempo)
#   ✓ Block Bootstrapping: Mejor CRPS=0.4738 [0.0s]
#   ✓ Sieve Bootstrap: Mejor CRPS=0.4785 [0.3s]
#   ✓ LSPMW: Mejor CRPS=0.4589 [0.1s]
#   ✓ AREPD: Mejor CRPS=0.4927 [0.3s]
#     Error en config {'n_lags': 10, 'n_bins': 8}: cannot pickle 'module' object
#     Error en config {'n_lags': 15, 'n_bins': 15}: cannot pickle 'module' object
#   ✓ MCPS: Mejor CRPS=inf [0.0s]
#     Error en config {'n_lags': 10, 'n_pred_bins': 8, 'n_vol_bins': 3}: cannot pickle 'module' object
#     Error en config {'n_lags': 15, 'n_pred_bins': 10, 'n_vol_bins': 5}: cannot pickle 'module' object
#   ✓ AV-MCPS: Mejor CRPS=inf [0.0s]
#   ✓ DeepAR: Mejor CRPS=0.5046 [17.8s]
#     Error en config {'n_lags': 10, 'units': 24, 'epochs': 20}: cannot pickle 'module' object
#     Error en config {'n_lags': 20, 'units': 32, 'epochs': 25}: cannot pickle 'module' object
#   ✓ EnCQR-LSTM: Mejor CRPS=inf [0.0s]
# ✅ Optimización completada en 18.58s
#
# 🔬 Iniciando pruebas en ventana deslizante...
#
#    Paso 1/12... ✓ (18.51s)
#    Paso 2/12... ✓ (0.40s)
#    Paso 3/12... ✓ (0.40s)
#    Paso 4/12... ✓ (0.39s)
#    Paso 5/12... ✓ (0.38s)
#    Paso 6/12... ✓ (0.39s)
#    Paso 7/12... ✓ (0.40s)
#    Paso 8/12... ✓ (0.39s)
#    Paso 9/12... ✓ (0.40s)
#    Paso 10/12... ✓ (0.41s)
#    Paso 11/12... ✓ (0.39s)
#    Paso 12/12... ✓ (0.39s)
#
# ✅ Resultados guardados en: test_results\test_SETAR_SETAR(2;2,2)_d1_r0_5_mixture_V1.0.xlsx
#
# ======================================================================

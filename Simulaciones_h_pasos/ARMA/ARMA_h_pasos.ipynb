# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones_h_pasos\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_two_scenarios

main_two_scenarios()  # Descomenta para correr solo 2 escenarios
# Out:
# ================================================================================
# EVALUACIÓN CON 2 ESCENARIOS (100 TRAYECTORIAS CADA UNO)
# ================================================================================
#
# 📊 Configuración:
#    - Escenarios: 2 (AR(1) y MA(1))
#    - Distribución: Normal
#    - Varianza: 1.0
#    - Trayectorias por modelo: 100
#    - Trayectorias teóricas: 1000
#
# ================================================================================
# 🚀 INICIANDO EVALUACIÓN DE 2 ESCENARIOS
# ================================================================================
# 📊 Configuración:
#    - Trayectorias por modelo: 100
#    - Muestras teóricas por paso: 1000
#    - Pasos de predicción: 12
#    - Procesos ARMA: 2
#    - Distribuciones: 1
#    - Varianzas: 1
#    - Procesos paralelos: 2
#    - Tamaño de lote: 10
#
# 📦 Procesando lote 1/1...
#    ✅ Lote 1 completado. Guardado intermedio en resultados_2_escenarios_trayectorias.xlsx
#
# ================================================================================
# ✅ PROCESO COMPLETADO
# ================================================================================
# 📁 Resultados guardados en: resultados_2_escenarios_trayectorias.xlsx
# 📊 Total de filas: 24
# 📈 Columnas: ['Paso', 'Paso_H', 'Config', 'Proceso', 'Dist', 'Distribución', 'Var', 'Varianza', 'LSPM', 'DeepAR', 'Sieve Bootstrap', 'MCPS']
#
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO DE RESULTADOS - 100 TRAYECTORIAS
# ================================================================================
#
# 🏆 1. RANKING GLOBAL (Media ECRPS)
# --------------------------------------------------------------------------------
# Rank   Modelo                    ECRPS Medio     Std
# ----------------------------------------------------------------------
# 1      Sieve Bootstrap           0.907698      0.218094
# 2      LSPM                      0.920490      0.219696
# 3      DeepAR                    0.925562      0.229450
# 4      MCPS                      1.063038      0.235218
#
# 🎯 2. VICTORIAS (Mejor modelo por cada paso-escenario)
# --------------------------------------------------------------------------------
#   Sieve Bootstrap          :   15 victorias (62.5%)
#   LSPM                     :    5 victorias (20.8%)
#   DeepAR                   :    4 victorias (16.7%)
#   MCPS                     :    0 victorias (0.0%)
#
# 📈 3. RENDIMIENTO POR HORIZONTE (Paso H)
# --------------------------------------------------------------------------------
#
# Paso   LSPM           DeepAR         Sieve BootstrapMCPS
# --------------------------------------------------------------------------------
# 1      0.595960       0.577620       0.573653       0.961018
# 2      0.742772       0.756096       0.733843       1.134637
# 3      0.857247       0.876477       0.832942       1.125671
# 4      0.887437       0.899621       0.882060       0.989919
# 5      0.934828       0.949705       0.916116       0.977377
# 6      0.931581       0.968506       0.929595       1.026613
# 7      1.019805       0.998813       0.987256       1.090210
# 8      0.987284       1.007245       0.996554       1.060889
# 9      1.043425       1.032228       1.016028       1.081953
# 10     1.006192       1.010819       1.004574       1.080659
# 11     1.021733       1.005479       1.001797       1.107652
# 12     1.017610       1.024138       1.017959       1.119859
#
# 🔄 4. RENDIMIENTO POR PROCESO ARMA
# --------------------------------------------------------------------------------
#
#   AR(1):
#     LSPM                : 1.075157 (1 victorias)
#     DeepAR              : 1.089649 (1 victorias)
#     Sieve Bootstrap     : 1.058328 (10 victorias)
#     MCPS                : 1.281744 (0 victorias)
#
#   MA(1):
#     LSPM                : 0.765822 (4 victorias)
#     DeepAR              : 0.761475 (3 victorias)
#     Sieve Bootstrap     : 0.757068 (5 victorias)
#     MCPS                : 0.844332 (0 victorias)
#
# 📊 5. RENDIMIENTO POR DISTRIBUCIÓN
# --------------------------------------------------------------------------------
#
#   normal:
#     LSPM                : 0.920490
#     DeepAR              : 0.925562
#     Sieve Bootstrap     : 0.907698
#     MCPS                : 1.063038
#
# 📉 6. RENDIMIENTO POR NIVEL DE VARIANZA
# --------------------------------------------------------------------------------
#
#   Varianza = 1.0:
#     LSPM                : 0.920490
#     DeepAR              : 0.925562
#     Sieve Bootstrap     : 0.907698
#     MCPS                : 1.063038
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# 📊 Generando gráficos de densidades...
#
# ⚠️ Error al generar gráficos: could not convert string to float: 'V1.0'
#    Los resultados en Excel están disponibles.
#
# ⏱  Tiempo total: 71.4s
#     Paso  Paso_H Config Proceso    Dist Distribución  Var  Varianza      LSPM  \
# 0      1       1  AR(1)   AR(1)  normal       normal  1.0       1.0  0.611174
# 1      2       2  AR(1)   AR(1)  normal       normal  1.0       1.0  0.798264
# 2      3       3  AR(1)   AR(1)  normal       normal  1.0       1.0  0.939310
# 3      4       4  AR(1)   AR(1)  normal       normal  1.0       1.0  1.025007
# 4      5       5  AR(1)   AR(1)  normal       normal  1.0       1.0  1.054461
# 5      6       6  AR(1)   AR(1)  normal       normal  1.0       1.0  1.097293
# 6      7       7  AR(1)   AR(1)  normal       normal  1.0       1.0  1.155142
# 7      8       8  AR(1)   AR(1)  normal       normal  1.0       1.0  1.169941
# 8      9       9  AR(1)   AR(1)  normal       normal  1.0       1.0  1.252400
# 9     10      10  AR(1)   AR(1)  normal       normal  1.0       1.0  1.235450
# 10    11      11  AR(1)   AR(1)  normal       normal  1.0       1.0  1.271892
# 11    12      12  AR(1)   AR(1)  normal       normal  1.0       1.0  1.291546
# 12     1       1  MA(1)   MA(1)  normal       normal  1.0       1.0  0.580745
# 13     2       2  MA(1)   MA(1)  normal       normal  1.0       1.0  0.687280
# 14     3       3  MA(1)   MA(1)  normal       normal  1.0       1.0  0.775185
# 15     4       4  MA(1)   MA(1)  normal       normal  1.0       1.0  0.749867
# 16     5       5  MA(1)   MA(1)  normal       normal  1.0       1.0  0.815196
# 17     6       6  MA(1)   MA(1)  normal       normal  1.0       1.0  0.765868
# 18     7       7  MA(1)   MA(1)  normal       normal  1.0       1.0  0.884468
# 19     8       8  MA(1)   MA(1)  normal       normal  1.0       1.0  0.804628
# 20     9       9  MA(1)   MA(1)  normal       normal  1.0       1.0  0.834450
# 21    10      10  MA(1)   MA(1)  normal       normal  1.0       1.0  0.776934
# 22    11      11  MA(1)   MA(1)  normal       normal  1.0       1.0  0.771575
# 23    12      12  MA(1)   MA(1)  normal       normal  1.0       1.0  0.743675
#
#       DeepAR  Sieve Bootstrap      MCPS
# 0   0.569013         0.573005  1.155115
# 1   0.804792         0.780782  1.375704
# 2   0.975346         0.918092  1.378856
# 3   1.030895         0.994871  1.179238
# 4   1.106563         1.045970  1.125297
# 5   1.154648         1.090040  1.203531
# 6   1.169621         1.155276  1.285071
# 7   1.190866         1.169254  1.240277
# 8   1.266546         1.222134  1.306974
# 9   1.249869         1.223601  1.348851
# 10  1.256877         1.247210  1.364864
# 11  1.300755         1.279704  1.417154
# 12  0.586227         0.574300  0.766921
# 13  0.707399         0.686905  0.893571
# 14  0.777608         0.747791  0.872485
# 15  0.768346         0.769249  0.800600
# 16  0.792846         0.786261  0.829457
# 17  0.782364         0.769150  0.849695
# 18  0.828004         0.819236  0.895348
# 19  0.823624         0.823854  0.881500
# 20  0.797910         0.809921  0.856931
# 21  0.771770         0.785547  0.812467
# 22  0.754081         0.756384  0.850440
# 23  0.747521         0.756213  0.822564

# %%
from runner import main_full_140

main_full_140()
# Out:
# ================================================================================
# SIMULACIÓN COMPLETA - 140 ESCENARIOS CON 100 TRAYECTORIAS
# ================================================================================
# ================================================================================
# 🚀 INICIANDO EVALUACIÓN DE 140 ESCENARIOS
# ================================================================================
# 📊 Configuración:
#    - Trayectorias por modelo: 100
#    - Muestras teóricas por paso: 1000
#    - Pasos de predicción: 12
#    - Procesos ARMA: 7
#    - Distribuciones: 5
#    - Varianzas: 4
#    - Procesos paralelos: 4
#    - Tamaño de lote: 10
#
# 📦 Procesando lote 1/14...
#    ✅ Lote 1 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 2/14...
#    ✅ Lote 2 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 3/14...
#    ✅ Lote 3 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 4/14...
#    ✅ Lote 4 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 5/14...
#    ✅ Lote 5 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 6/14...
#    ✅ Lote 6 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 7/14...
#    ✅ Lote 7 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 8/14...
#    ✅ Lote 8 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 9/14...
#    ✅ Lote 9 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 10/14...
#    ✅ Lote 10 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 11/14...
#    ✅ Lote 11 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 12/14...
#    ✅ Lote 12 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 13/14...
#    ✅ Lote 13 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
# 📦 Procesando lote 14/14...
#    ✅ Lote 14 completado. Guardado intermedio en resultados_140_trayectorias_FINAL.xlsx
#
# ================================================================================
# ✅ PROCESO COMPLETADO
# ================================================================================
# 📁 Resultados guardados en: resultados_140_trayectorias_FINAL.xlsx
# 📊 Total de filas: 1680
# 📈 Columnas: ['Paso', 'Paso_H', 'Config', 'Proceso', 'Dist', 'Distribución', 'Var', 'Varianza', 'LSPM', 'DeepAR', 'Sieve Bootstrap', 'MCPS']
#
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO DE RESULTADOS - 100 TRAYECTORIAS
# ================================================================================
#
# 🏆 1. RANKING GLOBAL (Media ECRPS)
# --------------------------------------------------------------------------------
# Rank   Modelo                    ECRPS Medio     Std
# ----------------------------------------------------------------------
# 1      Sieve Bootstrap           0.793567      0.601805
# 2      DeepAR                    0.833898      0.686251
# 3      LSPM                      0.863196      0.685296
# 4      MCPS                      0.885279      0.688316
#
# 🎯 2. VICTORIAS (Mejor modelo por cada paso-escenario)
# --------------------------------------------------------------------------------
#   Sieve Bootstrap          :  687 victorias (40.9%)
#   DeepAR                   :  447 victorias (26.6%)
#   LSPM                     :  358 victorias (21.3%)
#   MCPS                     :  188 victorias (11.2%)
#
# 📈 3. RENDIMIENTO POR HORIZONTE (Paso H)
# --------------------------------------------------------------------------------
#
# Paso   LSPM           DeepAR         Sieve BootstrapMCPS
# --------------------------------------------------------------------------------
# 1      0.686234       0.506750       0.496032       0.637429
# 2      0.662513       0.677624       0.652754       0.753428
# 3      0.842737       0.761542       0.729056       0.815631
# 4      0.821301       0.801874       0.766179       0.863288
# 5      0.919047       0.832616       0.799399       0.885599
# 6      0.900792       0.863354       0.830281       0.905344
# 7      0.913520       0.888005       0.847653       0.922574
# 8      0.908610       0.906337       0.859194       0.941542
# 9      0.896659       0.922355       0.871108       0.957837
# 10     0.940053       0.934273       0.883981       0.974464
# 11     0.928073       0.951781       0.889506       0.979663
# 12     0.938808       0.960266       0.897664       0.986550
#
# 🔄 4. RENDIMIENTO POR PROCESO ARMA
# --------------------------------------------------------------------------------
#
#   AR(1):
#     LSPM                : 0.955006 (68 victorias)
#     DeepAR              : 1.043311 (40 victorias)
#     Sieve Bootstrap     : 0.915503 (121 victorias)
#     MCPS                : 1.121844 (11 victorias)
#
#   AR(2):
#     LSPM                : 0.572966 (48 victorias)
#     DeepAR              : 0.548229 (70 victorias)
#     Sieve Bootstrap     : 0.548135 (88 victorias)
#     MCPS                : 0.569482 (34 victorias)
#
#   ARMA(1,1):
#     LSPM                : 0.810336 (36 victorias)
#     DeepAR              : 0.744393 (80 victorias)
#     Sieve Bootstrap     : 0.744776 (97 victorias)
#     MCPS                : 0.797923 (27 victorias)
#
#   ARMA(2,1):
#     LSPM                : 1.565914 (60 victorias)
#     DeepAR              : 1.561394 (27 victorias)
#     Sieve Bootstrap     : 1.411934 (119 victorias)
#     MCPS                : 1.690101 (34 victorias)
#
#   ARMA(2,2):
#     LSPM                : 0.828813 (17 victorias)
#     DeepAR              : 0.703611 (104 victorias)
#     Sieve Bootstrap     : 0.702703 (94 victorias)
#     MCPS                : 0.744294 (25 victorias)
#
#   MA(1):
#     LSPM                : 0.742572 (34 victorias)
#     DeepAR              : 0.671006 (79 victorias)
#     Sieve Bootstrap     : 0.664747 (89 victorias)
#     MCPS                : 0.688861 (38 victorias)
#
#   MA(2):
#     LSPM                : 0.566763 (95 victorias)
#     DeepAR              : 0.565343 (47 victorias)
#     Sieve Bootstrap     : 0.567173 (79 victorias)
#     MCPS                : 0.584450 (19 victorias)
#
# 📊 5. RENDIMIENTO POR DISTRIBUCIÓN
# --------------------------------------------------------------------------------
#
#   exponential:
#     LSPM                : 0.919234
#     DeepAR              : 0.905914
#     Sieve Bootstrap     : 0.870228
#     MCPS                : 0.995377
#
#   mixture:
#     LSPM                : 0.471906
#     DeepAR              : 0.454601
#     Sieve Bootstrap     : 0.396201
#     MCPS                : 0.507595
#
#   normal:
#     LSPM                : 0.989674
#     DeepAR              : 0.947647
#     Sieve Bootstrap     : 0.899310
#     MCPS                : 0.965528
#
#   t-student:
#     LSPM                : 0.908939
#     DeepAR              : 0.913117
#     Sieve Bootstrap     : 0.879274
#     MCPS                : 0.961618
#
#   uniform:
#     LSPM                : 1.026224
#     DeepAR              : 0.948213
#     Sieve Bootstrap     : 0.922825
#     MCPS                : 0.996277
#
# 📉 6. RENDIMIENTO POR NIVEL DE VARIANZA
# --------------------------------------------------------------------------------
#
#   Varianza = 0.2:
#     LSPM                : 0.387135
#     DeepAR              : 0.384781
#     Sieve Bootstrap     : 0.360089
#     MCPS                : 0.444631
#
#   Varianza = 0.5:
#     LSPM                : 0.617825
#     DeepAR              : 0.585679
#     Sieve Bootstrap     : 0.581745
#     MCPS                : 0.637369
#
#   Varianza = 1.0:
#     LSPM                : 0.894353
#     DeepAR              : 0.834423
#     Sieve Bootstrap     : 0.809806
#     MCPS                : 0.918023
#
#   Varianza = 3.0:
#     LSPM                : 1.553470
#     DeepAR              : 1.530710
#     Sieve Bootstrap     : 1.422629
#     MCPS                : 1.541093
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# 📊 Generando gráficos resumidos...
#
# ⏱  Tiempo total: 3542.2s (0.98 horas)
#       Paso  Paso_H     Config    Proceso     Dist Distribución  Var  Varianza  \
# 0        1       1      AR(1)      AR(1)   normal       normal  0.2       0.2
# 1        2       2      AR(1)      AR(1)   normal       normal  0.2       0.2
# 2        3       3      AR(1)      AR(1)   normal       normal  0.2       0.2
# 3        4       4      AR(1)      AR(1)   normal       normal  0.2       0.2
# 4        5       5      AR(1)      AR(1)   normal       normal  0.2       0.2
# ...    ...     ...        ...        ...      ...          ...  ...       ...
# 1675     8       8  ARMA(2,1)  ARMA(2,1)  mixture      mixture  3.0       3.0
# 1676     9       9  ARMA(2,1)  ARMA(2,1)  mixture      mixture  3.0       3.0
# 1677    10      10  ARMA(2,1)  ARMA(2,1)  mixture      mixture  3.0       3.0
# 1678    11      11  ARMA(2,1)  ARMA(2,1)  mixture      mixture  3.0       3.0
# 1679    12      12  ARMA(2,1)  ARMA(2,1)  mixture      mixture  3.0       3.0
#
#           LSPM    DeepAR  Sieve Bootstrap      MCPS
# 0     0.273326  0.254470         0.256256  0.516583
# 1     0.356995  0.359914         0.349176  0.615233
# 2     0.420072  0.436188         0.410583  0.616643
# 3     0.458397  0.461030         0.444920  0.527371
# 4     0.471569  0.494870         0.467772  0.503248
# ...        ...       ...              ...       ...
# 1675  1.146501  1.550143         1.394466  1.300345
# 1676  1.128541  1.442121         1.387130  1.634932
# 1677  1.463666  1.589536         1.475867  1.755553
# 1678  1.131255  1.708332         1.681192  1.716466
# 1679  1.316452  1.697791         1.581357  1.744839
#
# [1680 rows x 12 columns]

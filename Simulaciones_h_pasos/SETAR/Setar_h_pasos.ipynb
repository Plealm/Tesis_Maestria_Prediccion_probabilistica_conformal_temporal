# %%
# CELDA MÁGICA - EJECÚTALA PRIMERO EN TU NOTEBOOK ARMA.ipynb
import sys
import os

# Ruta al directorio que contiene todos los módulos (codigo_base)
CODE_BASE_PATH = r"C:\Users\pleal\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones_h_pasos\codigo_base"

# Añadimos al path para que Python los encuentre
if CODE_BASE_PATH not in sys.path:
    sys.path.insert(0, CODE_BASE_PATH)

print("Módulos cargados correctamente desde codigo_base")
print("Puedes usar: simulacion, pipeline, modelos, figuras, etc.")
# Out:
# Módulos cargados correctamente desde codigo_base
# Puedes usar: simulacion, pipeline, modelos, figuras, etc.

# %%
from runner import main_two_scenarios_setar

main_two_scenarios_setar()
# Out:
# ================================================================================
# EVALUACIÓN CON 2 ESCENARIOS SETAR (100 TRAYECTORIAS CADA UNO)
# ================================================================================
#
# 📊 Configuración:
#    - Escenarios: 2 (SETAR-1 simple y SETAR-3 moderado)
#    - SETAR-1: AR(1) en ambos regímenes, threshold=0.0, delay=1
#    - SETAR-3: AR(2) en ambos regímenes, threshold=0.5, delay=1
#    - Distribución: Normal
#    - Varianza: 1.0
#    - Trayectorias por modelo: 100
#    - Trayectorias teóricas: 1000
#
# ================================================================================
# 🚀 INICIANDO EVALUACIÓN DE 2 ESCENARIOS SETAR
# ================================================================================
# 📊 Configuración:
#    - Trayectorias por modelo: 100
#    - Muestras teóricas por paso: 1000
#    - Pasos de predicción: 12
#    - Procesos SETAR: 2
#    - Distribuciones: 1
#    - Varianzas: 1
#    - Procesos paralelos: 2
#    - Tamaño de lote: 10
#
# 📦 Procesando lote 1/1...
#    ✅ Lote 1 completado. Guardado intermedio en resultados_2_escenarios_trayectorias_setar.xlsx
#
# ================================================================================
# ✅ PROCESO COMPLETADO
# ================================================================================
# 📁 Resultados guardados en: resultados_2_escenarios_trayectorias_setar.xlsx
# 📊 Total de filas: 24
# 📈 Columnas: ['Paso', 'Paso_H', 'Config', 'Proceso', 'Descripción', 'Dist', 'Distribución', 'Var', 'Varianza', 'LSPM', 'DeepAR', 'Sieve Bootstrap', 'MCPS']
#
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO DE RESULTADOS - 100 TRAYECTORIAS
# ================================================================================
#
# 🏆 1. RANKING GLOBAL (Media ECRPS)
# --------------------------------------------------------------------------------
# Rank   Modelo                    ECRPS Medio     Std
# ----------------------------------------------------------------------
# 1      Sieve Bootstrap           0.617252      0.021341
# 2      LSPM                      0.617787      0.023210
# 3      DeepAR                    0.622829      0.027925
# 4      MCPS                      0.657528      0.075659
#
# 🎯 2. VICTORIAS (Mejor modelo por cada paso-escenario)
# --------------------------------------------------------------------------------
#   Sieve Bootstrap          :   12 victorias (50.0%)
#   LSPM                     :    6 victorias (25.0%)
#   DeepAR                   :    6 victorias (25.0%)
#   MCPS                     :    0 victorias (0.0%)
#
# 📈 3. RENDIMIENTO POR HORIZONTE (Paso H)
# --------------------------------------------------------------------------------
#
# Paso   LSPM           DeepAR         Sieve BootstrapMCPS
# --------------------------------------------------------------------------------
# 1      0.589476       0.583558       0.594197       0.882511
# 2      0.589000       0.591962       0.584933       0.617907
# 3      0.634697       0.639182       0.632332       0.680302
# 4      0.623808       0.615737       0.620432       0.625425
# 5      0.620524       0.621876       0.618155       0.625592
# 6      0.610454       0.607822       0.614479       0.611069
# 7      0.649668       0.656595       0.643781       0.661780
# 8      0.619279       0.627843       0.618563       0.641539
# 9      0.632206       0.632673       0.630780       0.671506
# 10     0.619577       0.650895       0.617701       0.640867
# 11     0.617723       0.638987       0.621806       0.621099
# 12     0.607037       0.606815       0.609864       0.610734
#
# 🔄 4. RENDIMIENTO POR PROCESO ARMA
# --------------------------------------------------------------------------------
#
#   SETAR-1:
#     LSPM                : 0.623265 (4 victorias)
#     DeepAR              : 0.632194 (4 victorias)
#     Sieve Bootstrap     : 0.626213 (4 victorias)
#     MCPS                : 0.666335 (0 victorias)
#
#   SETAR-3:
#     LSPM                : 0.612310 (2 victorias)
#     DeepAR              : 0.613463 (2 victorias)
#     Sieve Bootstrap     : 0.608291 (8 victorias)
#     MCPS                : 0.648720 (0 victorias)
#
# 📊 5. RENDIMIENTO POR DISTRIBUCIÓN
# --------------------------------------------------------------------------------
#
#   normal:
#     LSPM                : 0.617787
#     DeepAR              : 0.622829
#     Sieve Bootstrap     : 0.617252
#     MCPS                : 0.657528
#
# 📉 6. RENDIMIENTO POR NIVEL DE VARIANZA
# --------------------------------------------------------------------------------
#
#   Varianza = 1.0:
#     LSPM                : 0.617787
#     DeepAR              : 0.622829
#     Sieve Bootstrap     : 0.617252
#     MCPS                : 0.657528
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# 📊 Generando gráficos de densidades...
#
# ⚠️ Error al generar gráficos: type object 'PlotManager' has no attribute 'plot_scenario_densities'
#    Los resultados en Excel están disponibles.
#
# ⏱  Tiempo total: 93.7s
#     Paso  Paso_H   Config  Proceso              Descripción    Dist  \
# 0      1       1  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 1      2       2  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 2      3       3  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 3      4       4  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 4      5       5  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 5      6       6  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 6      7       7  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 7      8       8  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 8      9       9  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 9     10      10  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 10    11      11  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 11    12      12  SETAR-1  SETAR-1    SETAR(2;1,1) d=1, r=0  normal
# 12     1       1  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 13     2       2  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 14     3       3  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 15     4       4  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 16     5       5  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 17     6       6  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 18     7       7  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 19     8       8  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 20     9       9  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 21    10      10  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 22    11      11  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
# 23    12      12  SETAR-3  SETAR-3  SETAR(2;2,2) d=1, r=0.5  normal
#
#    Distribución  Var  Varianza      LSPM    DeepAR  Sieve Bootstrap      MCPS
# 0        normal  1.0       1.0  0.572871  0.569473         0.592562  0.858757
# 1        normal  1.0       1.0  0.614808  0.617623         0.604236  0.617305
# 2        normal  1.0       1.0  0.643658  0.650342         0.640601  0.713145
# 3        normal  1.0       1.0  0.653360  0.632855         0.639052  0.642231
# 4        normal  1.0       1.0  0.630566  0.629865         0.630390  0.640280
# 5        normal  1.0       1.0  0.613809  0.611587         0.631876  0.618609
# 6        normal  1.0       1.0  0.645326  0.680537         0.654592  0.653038
# 7        normal  1.0       1.0  0.597172  0.609476         0.596925  0.631327
# 8        normal  1.0       1.0  0.636411  0.638725         0.639095  0.715044
# 9        normal  1.0       1.0  0.622229  0.680124         0.620717  0.652921
# 10       normal  1.0       1.0  0.631128  0.646810         0.639971  0.632075
# 11       normal  1.0       1.0  0.617843  0.618915         0.624542  0.621287
# 12       normal  1.0       1.0  0.606082  0.597644         0.595833  0.906265
# 13       normal  1.0       1.0  0.563192  0.566300         0.565631  0.618509
# 14       normal  1.0       1.0  0.625736  0.628022         0.624063  0.647459
# 15       normal  1.0       1.0  0.594255  0.598619         0.601812  0.608619
# 16       normal  1.0       1.0  0.610481  0.613888         0.605920  0.610904
# 17       normal  1.0       1.0  0.607099  0.604057         0.597081  0.603530
# 18       normal  1.0       1.0  0.654009  0.632653         0.632969  0.670522
# 19       normal  1.0       1.0  0.641386  0.646211         0.640200  0.651750
# 20       normal  1.0       1.0  0.628001  0.626620         0.622464  0.627968
# 21       normal  1.0       1.0  0.616925  0.621667         0.614686  0.628813
# 22       normal  1.0       1.0  0.604319  0.631165         0.603641  0.610123
# 23       normal  1.0       1.0  0.596230  0.594715         0.595187  0.600181

# %%
from runner import main_full_140_setar

main_full_140_setar()
# Out:
# ================================================================================
# SIMULACIÓN COMPLETA SETAR - 140 ESCENARIOS CON 100 TRAYECTORIAS
# ================================================================================
# ================================================================================
# 🚀 INICIANDO EVALUACIÓN DE 140 ESCENARIOS SETAR
# ================================================================================
# 📊 Configuración:
#    - Trayectorias por modelo: 100
#    - Muestras teóricas por paso: 1000
#    - Pasos de predicción: 12
#    - Procesos SETAR: 7
#    - Distribuciones: 5
#    - Varianzas: 4
#    - Procesos paralelos: 4
#    - Tamaño de lote: 10
#
# 📦 Procesando lote 1/14...
#    ✅ Lote 1 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 2/14...
#    ✅ Lote 2 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 3/14...
#    ✅ Lote 3 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 4/14...
#    ✅ Lote 4 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 5/14...
#    ✅ Lote 5 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 6/14...
#    ✅ Lote 6 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 7/14...
#    ✅ Lote 7 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 8/14...
#    ✅ Lote 8 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 9/14...
#    ✅ Lote 9 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 10/14...
#    ✅ Lote 10 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 11/14...
#    ✅ Lote 11 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 12/14...
#    ✅ Lote 12 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 13/14...
#    ✅ Lote 13 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📦 Procesando lote 14/14...
#    ✅ Lote 14 completado. Guardado intermedio en resultados_140_trayectorias_SETAR_FINAL.xlsx
#
# ================================================================================
# ✅ PROCESO COMPLETADO
# ================================================================================
# 📁 Resultados guardados en: resultados_140_trayectorias_SETAR_FINAL.xlsx
# 📊 Total de filas: 1680
# 📈 Columnas: ['Paso', 'Paso_H', 'Config', 'Proceso', 'Descripción', 'Dist', 'Distribución', 'Var', 'Varianza', 'LSPM', 'DeepAR', 'Sieve Bootstrap', 'MCPS']
#
#
# ================================================================================
# ANÁLISIS EXHAUSTIVO DE RESULTADOS - 100 TRAYECTORIAS
# ================================================================================
#
# 🏆 1. RANKING GLOBAL (Media ECRPS)
# --------------------------------------------------------------------------------
# Rank   Modelo                    ECRPS Medio     Std
# ----------------------------------------------------------------------
# 1      DeepAR                    0.575966      0.341944
# 2      Sieve Bootstrap           0.583647      0.333322
# 3      LSPM                      0.594555      0.360196
# 4      MCPS                      0.611811      0.348783
#
# 🎯 2. VICTORIAS (Mejor modelo por cada paso-escenario)
# --------------------------------------------------------------------------------
#   Sieve Bootstrap          :  523 victorias (31.1%)
#   DeepAR                   :  499 victorias (29.7%)
#   LSPM                     :  482 victorias (28.7%)
#   MCPS                     :  176 victorias (10.5%)
#
# 📈 3. RENDIMIENTO POR HORIZONTE (Paso H)
# --------------------------------------------------------------------------------
#
# Paso   LSPM           DeepAR         Sieve BootstrapMCPS
# --------------------------------------------------------------------------------
# 1      0.617220       0.537736       0.547647       0.624923
# 2      0.616206       0.566928       0.573999       0.649747
# 3      0.623749       0.588059       0.579524       0.610162
# 4      0.591082       0.598939       0.592919       0.612153
# 5      0.585793       0.579032       0.594332       0.612282
# 6      0.589223       0.576121       0.584563       0.609630
# 7      0.592069       0.580891       0.591304       0.609340
# 8      0.583277       0.578860       0.591829       0.609282
# 9      0.586223       0.579079       0.586357       0.606268
# 10     0.583143       0.575834       0.591236       0.600078
# 11     0.586998       0.573120       0.581973       0.599748
# 12     0.579676       0.576988       0.588086       0.598120
#
# 🔄 4. RENDIMIENTO POR PROCESO ARMA
# --------------------------------------------------------------------------------
#
#   SETAR-1:
#     LSPM                : 0.560204 (55 victorias)
#     DeepAR              : 0.545568 (73 victorias)
#     Sieve Bootstrap     : 0.562339 (89 victorias)
#     MCPS                : 0.595488 (23 victorias)
#
#   SETAR-2:
#     LSPM                : 0.723426 (56 victorias)
#     DeepAR              : 0.662591 (76 victorias)
#     Sieve Bootstrap     : 0.666291 (83 victorias)
#     MCPS                : 0.703647 (25 victorias)
#
#   SETAR-3:
#     LSPM                : 0.546936 (79 victorias)
#     DeepAR              : 0.540191 (71 victorias)
#     Sieve Bootstrap     : 0.554731 (60 victorias)
#     MCPS                : 0.575643 (30 victorias)
#
#   SETAR-4:
#     LSPM                : 0.719164 (67 victorias)
#     DeepAR              : 0.702695 (66 victorias)
#     Sieve Bootstrap     : 0.680079 (74 victorias)
#     MCPS                : 0.728942 (33 victorias)
#
#   SETAR-5:
#     LSPM                : 0.521940 (77 victorias)
#     DeepAR              : 0.508137 (75 victorias)
#     Sieve Bootstrap     : 0.526641 (68 victorias)
#     MCPS                : 0.538990 (20 victorias)
#
#   SETAR-6:
#     LSPM                : 0.574006 (64 victorias)
#     DeepAR              : 0.552910 (71 victorias)
#     Sieve Bootstrap     : 0.576366 (85 victorias)
#     MCPS                : 0.602027 (20 victorias)
#
#   SETAR-7:
#     LSPM                : 0.516208 (84 victorias)
#     DeepAR              : 0.519668 (67 victorias)
#     Sieve Bootstrap     : 0.519084 (64 victorias)
#     MCPS                : 0.537941 (25 victorias)
#
# 📊 5. RENDIMIENTO POR DISTRIBUCIÓN
# --------------------------------------------------------------------------------
#
#   exponential:
#     LSPM                : 0.608585
#     DeepAR              : 0.614094
#     Sieve Bootstrap     : 0.610032
#     MCPS                : 0.633063
#
#   mixture:
#     LSPM                : 0.367971
#     DeepAR              : 0.305961
#     Sieve Bootstrap     : 0.364025
#     MCPS                : 0.399289
#
#   normal:
#     LSPM                : 0.670041
#     DeepAR              : 0.650517
#     Sieve Bootstrap     : 0.651283
#     MCPS                : 0.679593
#
#   t-student:
#     LSPM                : 0.634051
#     DeepAR              : 0.637214
#     Sieve Bootstrap     : 0.625510
#     MCPS                : 0.650385
#
#   uniform:
#     LSPM                : 0.692126
#     DeepAR              : 0.672042
#     Sieve Bootstrap     : 0.667387
#     MCPS                : 0.696726
#
# 📉 6. RENDIMIENTO POR NIVEL DE VARIANZA
# --------------------------------------------------------------------------------
#
#   Varianza = 0.2:
#     LSPM                : 0.275578
#     DeepAR              : 0.262788
#     Sieve Bootstrap     : 0.267669
#     MCPS                : 0.288478
#
#   Varianza = 0.5:
#     LSPM                : 0.439259
#     DeepAR              : 0.416677
#     Sieve Bootstrap     : 0.437624
#     MCPS                : 0.458411
#
#   Varianza = 1.0:
#     LSPM                : 0.598898
#     DeepAR              : 0.598803
#     Sieve Bootstrap     : 0.592819
#     MCPS                : 0.622850
#
#   Varianza = 3.0:
#     LSPM                : 1.064484
#     DeepAR              : 1.025594
#     Sieve Bootstrap     : 1.036478
#     MCPS                : 1.077505
#
# ================================================================================
# FIN DEL ANÁLISIS
# ================================================================================
#
# 📊 Generando gráficos resumidos...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 from runner import main_full_140_setar
# ----> 3 main_full_140_setar()
#
# File ~\Documents\Unal\Tesis\Codigo\Prediccion_Probabilistica\codigo_final_organizado\Simulaciones_h_pasos\codigo_base\runner.py:467, in main_full_140_setar()
#     464     step_data = df_final[df_final['Paso_H'] == h][model_cols].mean().to_frame().T
#     465     results_by_step[h] = step_data
# --> 467 PlotManager.plot_ecrps_evolution(
#     468     results_by_step, model_cols,
#     469     save_path="evolucion_ecrps_horizonte_setar.png"
#     470 )
#     472 # Resumen general
#     473 PlotManager.plot_results_summary(
#     474     df_final, model_cols,
#     475     step_name="Todos los escenarios SETAR",
#     476     save_path="resumen_global_ecrps_setar.png"
#     477 )
#
# AttributeError: type object 'PlotManager' has no attribute 'plot_ecrps_evolution'
